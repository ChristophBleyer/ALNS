# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=10,10

# %% [markdown]
# # Linear fixed end RRT

# %%
print("Average: ", np.average([430.2872875, 430.4413533333333, 430.43028583333336, 432.0555908333333, 432.7522925, 432.45396999999997, 431.37518833333337, 429.5825658333333, 430.9271775, 431.1789158333333, 429.3955825, 431.1786016666667, 431.16009833333334, 431.6127025, 435.3313725, 431.42312999999996]))


linearRRT = [430.2872875, 430.4413533333333, 430.43028583333336, 432.0555908333333, 432.7522925, 432.45396999999997, 431.37518833333337, 429.5825658333333, 430.9271775, 431.1789158333333, 429.3955825, 431.1786016666667, 431.16009833333334, 431.6127025, 435.3313725, 431.42312999999996]
x = range(1, len(linearRRT)+1)
ax.set_title(" average objetive of all runs on all test instances ")
plt.xlabel("iteration")
plt.plot(x, linearRRT, label="average objetive")
plt.legend(loc="upper left")
ax = plt.gca()
plt.xticks(range(1, len(linearRRT)+1))
ax.set_xlim(0, 17)
plt.show()
# Out:
# Average:  431.3491321875

# %% [markdown]
# # Exponential Fixed End Simulated Annealing

# %%
print("Average: ", np.average([430.13796083333335, 440.46103333333326, 433.85356833333327, 441.15204250000005, 430.83400666666665, 431.12175083333324, 430.2273416666667, 440.8995158333333, 439.5037608333334, 444.77059749999995, 430.97003333333333, 430.71683, 431.32240083333335, 432.2411991666666, 430.90746916666666, 431.3561833333333]))

ExpSA = [430.13796083333335, 440.46103333333326, 433.85356833333327, 441.15204250000005, 430.83400666666665, 431.12175083333324, 430.2273416666667, 440.8995158333333, 439.5037608333334, 444.77059749999995, 430.97003333333333, 430.71683, 431.32240083333335, 432.2411991666666, 430.90746916666666, 431.3561833333333]
x = range(1, len(ExpSA)+1)
ax.set_title(" average objetive of all runs on all test instances ")
plt.xlabel("iteration")
plt.plot(x, ExpSA, label="average objetive")
plt.legend(loc="upper left")
ax = plt.gca()
plt.xticks(range(1, len(ExpSA)+1))
ax.set_xlim(0, 17)
plt.show()
# Out:
# Average:  434.4047308854166

# %% [markdown]
# # Linear Fixed End Linear TA

# %%
print("Average: ", np.average([433.4494358333333, 432.2280925, 433.1383675, 431.12439583333327, 430.58166, 429.61105916666673, 430.8190808333333, 431.0439633333333, 429.74133666666665, 433.8960966666666, 432.66495416666663, 430.23978166666666, 429.76618666666667, 430.8877966666667, 433.94434999999993, 432.15496916666666]))

LinearTA = [433.4494358333333, 432.2280925, 433.1383675, 431.12439583333327, 430.58166, 429.61105916666673, 430.8190808333333, 431.0439633333333, 429.74133666666665, 433.8960966666666, 432.66495416666663, 430.23978166666666, 429.76618666666667, 430.8877966666667, 433.94434999999993, 432.15496916666666]
x = range(1, len(LinearTA)+1)
plt.plot(x, y, label="average objetive")
ax.set_title(" average objetive of all runs on all test instances ")
plt.xlabel("iteration")
plt.legend(loc="upper left")
ax = plt.gca()
plt.xticks(range(1, len(ExpSA)+1))
ax.set_xlim(0, 17)
plt.show()
# Out:
# Average:  431.5807204166666

# %% [markdown]
# # Comparison

# %%
plt.boxplot ([linearRRT, ExpSA, LinearTA])
labels = ('Linear fixed end RRT', 'Exponential fixed end SA', 'Linear fixed end TA')
plt.xticks(np.arange(len(labels))+1,labels)
plt.ylabel("average objective")
plt.show()

# %%
linearRRT2 = [431.1793974999999, 446.93012500000003, 444.938065, 444.82521249999996, 436.7043683333333, 434.7276075, 469.1730791666667, 431.71623500000004, 443.3695533333333, 442.35821166666665]
SA2 = [432.6790533333333, 460.28701666666666, 442.4020775000001, 446.3730966666667, 458.7824375, 452.15009833333335, 430.12335333333334, 445.5634383333333, 451.21702916666663, 459.7532283333333]
LA2 = [454.6861658333333, 456.2672016666667, 465.5063875, 469.70155083333333, 463.1291125, 483.8907474999999, 468.15866083333344, 452.71096833333337, 450.22231416666665, 457.9192783333333]
plt.boxplot ([linearRRT2, SA2, LA2], showfliers= False)

labels = ('Linear fixed end RRT', 'Exponential fixed end SA', 'Linear fixed end TA')
plt.xticks(np.arange(len(labels))+1,labels)
plt.ylabel("average objective")
plt.show()
